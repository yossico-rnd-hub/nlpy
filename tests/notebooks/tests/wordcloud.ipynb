# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

import spacy
nlp = spacy.load('en')

# Read the text.
file = '../../docs/text6'
with open(file, 'r') as f:
    text = f.read()
    doc = nlp(text)
    string = ' '.join(t.lemma_ for t in doc if not t.is_punct and not t.lemma_ == '-PRON-')

stopwords = set(STOPWORDS)
stopwords.update(["say"])

# Generate a word cloud image
# (lower max_font_size)
wordcloud = WordCloud(
    max_font_size=50,
     max_words=1000, 
    background_color="white",
    stopwords=stopwords,
).generate(string)

# Display the generated image:
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# Load all necessary libraries
import numpy as np
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
# %matplotlib inline
                                    
# Read the text.
file = '../../docs/text6'
with open(file, 'r') as f:
    text = f.read()

stopwords = set(STOPWORDS)
stopwords.update(["earlier", "week", "tell"])

# Generate a word cloud image
# (lower max_font_size, change the maximum number of word and lighten the background)
mask = np.array(Image.open('images/mask.png'))
wordcloud = WordCloud(
#     max_font_size=50, 
    max_words=1000, 
    background_color="white",
    stopwords=stopwords,
    mask=mask,
).generate(text)

# Display the generated image:
plt.figure(figsize=(10,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# Save the image in the img folder:
# wordcloud.to_file("images/wordcloud.png")
